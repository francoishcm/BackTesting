# %% [markdown]
# <a href="https://colab.research.google.com/github/francoishcm/BackTesting/blob/master/Momentum_Ranking_Model_revised3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Install packages

# %%
# !pip install yfinance

# %%
# !pip install yahooquery

# %%
# !pip install stockstats

# %%
# !pip install mpld3

# %% [markdown]
# ###Modules and settings

# %%
# %matplotlib inline
import datetime
from datetime import date
import pandas as pd
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from pathlib import Path
import pandas as pd
import numpy as np
from scipy import stats
import mpld3
mpld3.enable_notebook()
"""
Settings
"""
portfolio_value = 156787.84
perf_last_month = 156787.84
start = "2020-01-01"
end = "2023-09-01"
ranking_day = "2023-08-29"
index_date = 'STXCAP29082023.csv'
ranking_table ="ranking_table290823.csv"
portfolio = "portfolio290823.csv"
current_portfolio = "portfolio_140723.csv"

# Storing today's date into a variable
today = date.today()
# Storing the specific date
trading_day = today
# Calculate percent difference since last month
perf_pct = (portfolio_value / perf_last_month) - 1
# Print performance, format as percent with two decimals.
print("{} - Last Month Result: {:.2%}".format(trading_day, perf_pct))
# Remember today's portfolio value for next month's calculation
#perf_last_month = portfolio_value
# Out:
# 2023-08-29 - Last Month Result: 0.00%

# %% [markdown]
# ###Import Market Data

# %%
#Import required libraries
import pandas as pd
import json
import requests
import glob
import os
from yahooquery import Ticker
from datetime import datetime

now = datetime.now().strftime("%Y-%m-%d")
data = yf.Ticker("STXCAP.JO")
index = data.history(start=start,  end=end)
resetindex = index.reset_index(inplace = True)

index['Date'] = pd.to_datetime(index['Date']).dt.strftime('%Y-%m-%d')

index = index.drop(columns=(['Open', 'High','Low','Volume','Dividends','Stock Splits']))

index.set_index("Date", inplace=True)

index.to_csv(index_date)
STX = pd.read_csv(index_date,index_col='Date', parse_dates=['Date'])
STX['SMA'] = STX['Close'].rolling(200).mean()
STX.plot()
STX['diff'] = STX['Close'] - STX['SMA']
print(STX.tail(1))


params = {'access_key': 'e52cf3b93696352e880916f8c8adbf0c',
          'limit': 350}
api_result = requests.get('http://api.marketstack.com/v1/exchanges/XJSE/tickers', params)
api_response = api_result.json()
print(f"Exchange Name = {api_response['data']['name']}")
for ticker in api_response['data']['tickers']:
  print(f"{ticker['name']}: {ticker['symbol']}")


# Serializing json
json_object = json.dumps(api_response, indent=4)
# Writing to sample.json
with open("jse.json", "w") as outfile:
    outfile.write(json_object)

# Opening JSON file
with open('jse.json', 'r') as openfile:
    # Reading from json file
    json_object = json.load(openfile)
df1 = pd.json_normalize(json_object["data"]["tickers"])

# dropping null value columns to avoid errors
# new data frame with split value columns
new = df1["symbol"].str.split(".", n = 1, expand = True)
# making separate first name column from new data frame
df1["ticker"]= new[0]
# Dropping old Name columns
df1.drop(columns =["has_intraday","has_eod"], inplace = True)
new.columns = new.columns.astype(str)
new.columns.values[1] = "tickers"
new['0'] + '.' + new['tickers']
new.replace("XJSE", "JO", inplace=True)

result = pd.concat([df1, new], axis=1, join='inner')
df2=result['0'] + '.' + result['tickers']
final = pd.concat([df1, df2], axis=1, join='inner')
final.columns.values[3] = "tickers"
final.columns = final.columns.astype(str)
#Dropping old Name columns
final.drop(columns =["name", "symbol","ticker"], inplace = True)
# Converting a specific Dataframe
# column to list using Series.tolist()
xjse = final["tickers"].tolist()
print("Converting tickers to list...")
print("Output dataframe..." )
print("Writing csv file..." )
print("Saving JSE data to disc...")
print("Saving csv files for each stock to disc...")
symbols = xjse
tickers = Ticker(symbols, asynchronous=True)
data = tickers.history(start= start, end=end, interval='1d')
data= data.drop(['adjclose','dividends','splits'],axis=1)


#Convert dataframe to csv and save to disc
final.to_csv("tickers.csv")
data.to_csv("jse_stocks.csv")

resetindex = data.reset_index(inplace = True)

for i, g in data.groupby('symbol'):
    g.to_csv('/content/Stocks/{}.csv'.format(i), header=True, index_label=False)

# merging the files
joined_files = os.path.join("/content/Stocks/", "*.csv")

# A list of all joined files is returned
joined_list = glob.glob(joined_files)

# Finally, the files are joined
df = pd.concat(map(pd.read_csv, joined_list), ignore_index=True)

# new dataframe with different column order
df_new = df.iloc[:, [1, 2, 3, 4, 5, 6, 0]]

Tickers = df_new["symbol"].tolist()
mylist = list(dict.fromkeys(Tickers))
df = pd.DataFrame (mylist, columns = ['tickers'])
df.to_csv("/content/tickers.csv")

#Change date format to Year-Month-Day
df_new['date'] =  pd.to_datetime(df_new['date']).dt.strftime('%Y-%m-%d')

df_new.set_index('date', inplace=True)

for i, g in df_new.groupby('symbol'):
    g.to_csv('/content/Stocks_final3/{}.csv'.format(i), header=True, index_label=False)

symbols = xjse
tickers = Ticker(symbols, asynchronous=True)
data = tickers.history(start=start, end=end, interval='1d')
data= data.drop(['adjclose','dividends','splits'],axis=1)

resetindex = data.reset_index(inplace = True)

# new dataframe with different column order
df_new = data.iloc[:, [1, 2, 3, 4, 5, 6, 0]]

Tickers = df_new["symbol"].tolist()
mylist = list(dict.fromkeys(Tickers))
df = pd.DataFrame (mylist, columns = ['tickers'])
df.columns = df.iloc[1]

df.to_csv("/content/Stocks_final3/tickers.csv")


csv_folder = Path('/content/Stocks_final3')

for file in csv_folder.glob('*.JO.csv'): #create iteratable & iterate on it.
    mydata = pd.read_csv(file)
    mydata.reset_index(inplace = True)
    mydata = mydata.rename(columns={'index': 'date'}, index=None)
    mydata['date'] =  pd.to_datetime(mydata['date']).dt.strftime('%Y-%m-%d')
    mydata.set_index('date', inplace=True)
    df =mydata[["open","high","low","close","volume"]]
    no_outlier_prices = df[(np.abs(stats.zscore(df)) <3).all(axis=1)]
    new_file_name = file.parent.joinpath(f"{file.stem}.csv")
    no_outlier_prices.to_csv(new_file_name) #, index=None, encoding='utf-8-sig', decimal=',')
# Out:
#              Close         SMA      diff
# Date
# 2023-08-29  3759.0  3808.92188 -49.92188
# Exchange Name = Johannesburg Stock Exchange
# PROSUS N.V.: PRX.XJSE
# ANHEUSER-BUSCH INBEV SA NV: ANH.XJSE
# BHP GROUP PLC: BHP.XJSE
# BRITISH AMERICAN TOB PLC: BTI.XJSE
# NASPERS LTD -N-: NPN.XJSE
# COMPAGNIE FIN RICHEMONT: CFR.XJSE
# GLENCORE PLC: GLN.XJSE
# ANGLO AMERICAN PLC: AGL.XJSE
# FIRSTRAND LTD: FSR.XJSE
# ANGLO AMERICAN PLAT LTD: AMS.XJSE
# STANDARD BANK GROUP LTD: SBK.XJSE
# VODACOM GROUP LTD: VOD.XJSE
# MONDI PLC: MNP.XJSE
# CAPITEC BANK HLDGS LTD: CPI.XJSE
# BEE - SASOL LIMITED: SOLBE1.XJSE
# SANLAM LIMITED: SLM.XJSE
# MTN GROUP LTD: MTN.XJSE
# ANGLOGOLD ASHANTI LTD: ANG.XJSE
# SASOL LIMITED: SOL.XJSE
# ABSA GROUP LIMITED: ABG.XJSE
# SOUTH32 LIMITED: S32.XJSE
# RMB HOLDINGS LTD: RMH.XJSE
# IMPALA PLATINUM HLGS LTD: IMP.XJSE
# BID CORPORATION LTD: BID.XJSE
# REMGRO LTD: REM.XJSE
# KUMBA IRON ORE LTD: KIO.XJSE
# NEDBANK GROUP LTD: NED.XJSE
# SIBANYE STILLWATER LTD: SSW.XJSE
# GOLD FIELDS LTD: GFI.XJSE
# INVESTEC LTD: INL.XJSE
# INVESTEC PLC: INP.XJSE
# OLD MUTUAL LIMITED: OMU.XJSE
# NEPI ROCKCASTLE PLC: NRP.XJSE
# DISCOVERY LTD: DSY.XJSE
# SHOPRITE HOLDINGS LTD: SHP.XJSE
# BIDVEST LTD: BVT.XJSE
# REINET INVESTMENTS S.C.A: RNI.XJSE
# CLICKS GROUP LTD: CLS.XJSE
# PEPKOR HOLDINGS LTD: PPH.XJSE
# QUILTER PLC: QLT.XJSE
# GROWTHPOINT PROP LTD: GRT.XJSE
# MEDICLINIC INT PLC: MEI.XJSE
# ASPEN PHARMACARE HLDGS LTD: APN.XJSE
# PSG GROUP LTD: PSG.XJSE
# MULTICHOICE GROUP LTD: MCG.XJSE
# MR PRICE GROUP LTD: MRP.XJSE
# NORTHAM PLATINUM LTD: NHM.XJSE
# RAND MERCHANT INV HLDGS LTD: RMI.XJSE
# FORTRESS REIT LTD A: FFA.XJSE
# WOOLWORTHS HOLDINGS LTD: WHL.XJSE
# CAPITAL&COUNTIES PROP PLC: CCO.XJSE
# LIFE HEALTHC GRP HLDGS LTD: LHC.XJSE
# HAMMERSON PLC: HMN.XJSE
# THE SPAR GROUP LTD: SPP.XJSE
# HARMONY GM CO LTD: HAR.XJSE
# REDEFINE PROPERTIES LTD: RDF.XJSE
# THE FOSCHINI GROUP LIMITED: TFG.XJSE
# EXXARO RESOURCES LTD: EXX.XJSE
# SANTAM LIMITED: SNT.XJSE
# AFRICAN RAINBOW MIN LTD: ARI.XJSE
# PICK N PAY STORES LTD: PIK.XJSE
# MOMENTUM MET HLDGS LTD: MTM.XJSE
# LIBERTY HOLDINGS LTD: LBH.XJSE
# VIVO ENERGY PLC: VVO.XJSE
# TIGER BRANDS LTD: TBS.XJSE
# NETCARE LIMITED: NTC.XJSE
# AVI LTD: AVI.XJSE
# DISTELL GROUP HLDGS LTD: DGH.XJSE
# PIONEER FOODS GROUP LTD: PFG.XJSE
# RESILIENT REIT LIMITED: RES.XJSE
# TRUWORTHS INT LTD: TRU.XJSE
# DIS-CHEM PHARMACIES LTD: DCP.XJSE
# ASSORE LTD: ASR.XJSE
# GLOBE TRADE CENTRE S.A.: GTC.XJSE
# BARLOWORLD LTD: BAW.XJSE
# SIRIUS REAL ESTATE LTD: SRE.XJSE
# SAPPI LTD: SAP.XJSE
# ITALTILE LTD: ITE.XJSE
# EPP N.V.: EPP.XJSE
# VUKILE PROPERTY FUND LTD: VKE.XJSE
# MOTUS HOLDINGS LTD: MTH.XJSE
# CORONATION FUND MNGRS LD: CML.XJSE
# TELKOM SA SOC LTD: TKG.XJSE
# ROYAL BAFOKENG PLATINUM LTD: RBP.XJSE
# MAS REAL ESTATE INC.: MSP.XJSE
# HYPROP INV LTD: HYP.XJSE
# TRANSACTION CAPITAL LTD: TCP.XJSE
# FORTRESS REIT LTD B: FFB.XJSE
# ARROWHEAD PROP LTD A: AHA.XJSE
# PSG KONSULT LIMITED: KST.XJSE
# AECI LIMITED: AFE.XJSE
# RCL FOODS LIMITED: RCL.XJSE
# MASSMART HOLDINGS LTD: MSM.XJSE
# EQUITES PROP FUND LTD: EQU.XJSE
# INVESTEC PROPERTY FUND LTD: IPF.XJSE
# REUNERT LTD: RLO.XJSE
# TSOGO SUN GAMING LTD: TSG.XJSE
# IMPERIAL LOGISTICS LTD: IPL.XJSE
# JSE LTD: JSE.XJSE
# DRD GOLD LTD: DRD.XJSE
# RDI REIT P.L.C: RPL.XJSE
# SUPER GROUP LTD: SPG.XJSE
# KAP INDUSTRIAL HLDGS LTD: KAP.XJSE
# ALLIED ELECTRONICS CORP A: AEL.XJSE
# TEXTAINER GROUP HLDGS LTD: TXT.XJSE
# ASTRAL FOODS LTD: ARL.XJSE
# ZEDER INV LTD: ZED.XJSE
# CARTRACK HOLDINGS LTD: CTK.XJSE
# ADCOCK INGRAM HLDGS LTD: AIP.XJSE
# STENPROP LIMITED: STP.XJSE
# ATTACQ LIMITED: ATT.XJSE
# OCEANA GROUP LTD: OCE.XJSE
# DATATEC LTD: DTC.XJSE
# EMIRA PROPERTY FUND LTD: EMI.XJSE
# MONTAUK HOLDINGS LTD: MNK.XJSE
# AFRICAN OXYGEN LIMITED: AFX.XJSE
# HOSKEN CONS INV LTD: HCI.XJSE
# ALEXANDER FORBES GRP HLDGS: AFH.XJSE
# STEINHOFF INT HLDGS N.V.: SNH.XJSE
# FAMOUS BRANDS LTD: FBR.XJSE
# WILSON BAYLY HLM-OVC LTD: WBO.XJSE
# SA CORP REAL ESTATE LTD: SAC.XJSE
# STOR-AGE PROP REIT LTD: SSS.XJSE
# ADVTECH LTD: ADH.XJSE
# TRUSTCO GROUP HLDGS LTD: TTO.XJSE
# LIBERTY TWO DEGREES LTD: L2D.XJSE
# LIGHTHOUSE CAPITAL LTD: LTE.XJSE
# GRIT REAL ESTATE INC GRP: GTR.XJSE
# CURRO HOLDINGS LIMITED: COH.XJSE
# DIPULA INCOME FUND A: DIA.XJSE
# PAN AFRICAN RESOURCE PLC: PAN.XJSE
# MIX TELEMATICS LTD: MIX.XJSE
# LIBSTAR HOLDINGS LTD: LBR.XJSE
# CLIENTELE LTD: CLI.XJSE
# RAVEN PROPERTY GROUP LTD: RAV.XJSE
# BRAIT SE: BAT.XJSE
# OMNIA HOLDINGS LTD: OMN.XJSE
# SEA HARVEST GROUP LTD: SHG.XJSE
# SUN INTERNATIONAL LTD: SUI.XJSE
# METAIR INVESTMENTS LTD: MTA.XJSE
# AFRIMAT LIMITED: AFT.XJSE
# CAPITAL & REGIONAL PLC: CRP.XJSE
# RAUBEX GROUP LTD: RBX.XJSE
# HOMECHOICE INT PLC: HIL.XJSE
# CASHBUILD LTD: CSB.XJSE
# RHODES FOOD GRP HLDG LTD: RFG.XJSE
# PEREGRINE HOLDINGS LIMITED: PGR.XJSE
# MURRAY & ROBERTS HLDGS: MUR.XJSE
# OCTODEC INVEST LTD: OCT.XJSE
# INTU PROPERTIES PLC: ITU.XJSE
# HOSPITALITY PROP FUND B: HPB.XJSE
# TSOGO SUN HOTELS LTD: TGO.XJSE
# ARROWHEAD PROP LTD B: AHB.XJSE
# THARISA PLC: THA.XJSE
# AFRICAN RAINBOW CAP INV: AIL.XJSE
# HUDACO INDUSTRIES LTD: HDC.XJSE
# EXEMPLAR REITAIL LTD: EXP.XJSE
# GRINDROD LTD: GND.XJSE
# NET 1 UEPS TECH INC: NT1.XJSE
# HERIOT REIT LIMITED: HET.XJSE
# ATLANTIC LEAF PROP LTD: ALP.XJSE
# SCHRODER EUR REIT PLC: SCD.XJSE
# LONG 4 LIFE LIMITED: L4L.XJSE
# FINBOND GROUP LTD: FGL.XJSE
# TRADEHOLD LTD: TDH.XJSE
# ACSION LIMITED: ACS.XJSE
# CAXTON CTP PUBLISH PRINT: CAT.XJSE
# PPC LIMITED: PPC.XJSE
# MPACT LIMITED: MPT.XJSE
# BLUE LABEL TELECOMS LTD: BLU.XJSE
# LEWIS GROUP LTD: LEW.XJSE
# SPUR CORPORATION LTD: SUR.XJSE
# GEMFIELDS GROUP LIMITED: GML.XJSE
# CITY LODGE HOTELS LTD: CLH.XJSE
# E MEDIA HOLDINGS LTD -N-: EMN.XJSE
# NAMPAK LTD: NPK.XJSE
# ENX GROUP LIMITED: ENX.XJSE
# KAAP AGRI LIMITED: KAL.XJSE
# FAIRVEST PROPERTY HLDGS: FVT.XJSE
# ALPHAMIN RESOURCES CORP: APH.XJSE
# SPEAR REIT LIMITED: SEA.XJSE
# SABVEST LTD: SBV.XJSE
# RENERGEN LIMITED: REN.XJSE
# AFROCENTRIC INV CORP LTD: ACT.XJSE
# BRIMSTONE INV CORP LTD-N: BRN.XJSE
# EPE CAPITAL PARTNERS LTD: EPE.XJSE
# BALWIN PROPERTIES LTD: BWN.XJSE
# BRIMSTONE INV CORP LTD: BRT.XJSE
# TRENCOR LTD: TRE.XJSE
# MASTER DRILLING GRP LTD: MDI.XJSE
# GRAND PARADE INV LTD: GPL.XJSE
# SABVEST LTD -N-: SVN.XJSE
# OANDO PLC: OAO.XJSE
# JUBILEE METALS GROUP PLC: JBL.XJSE
# COMBINED MOTOR HLDGS LTD: CMH.XJSE
# SYGNIA LIMITED: SYG.XJSE
# STADIO HOLDINGS LIMITED: SDO.XJSE
# E MEDIA HOLDINGS LTD: EMH.XJSE
# GRINDROD SHIPPING HLDG LTD: GSH.XJSE
# TOWER PROPERTY FUND LTD: TWR.XJSE
# ACCELERATE PROP FUND LTD: APF.XJSE
# METROFILE HOLDINGS LTD: MFL.XJSE
# SAFARI INVESTMENTS RSA LTD: SAR.XJSE
# MERAFE RESOURCES LTD: MRF.XJSE
# COMAIR LIMITED: COM.XJSE
# MTN ZAKHELE FUTHI: MTNZF.XJSE
# ADCORP HOLDINGS LIMITED: ADR.XJSE
# INDLUPLACE PROPERTIES LTD: ILU.XJSE
# DIPULA INCOME FUND B: DIB.XJSE
# HOSKEN PAX LOG AND RAIL: HPR.XJSE
# ARCELORMITTAL SA LIMITED: ACL.XJSE
# ALVIVA HOLDINGS LTD: AVV.XJSE
# INVICTA HOLDINGS LTD: IVT.XJSE
# ARB HOLDINGS LIMITED: ARH.XJSE
# TISO BLACKSTAR GROUP SE: TBG.XJSE
# ZARCLEAR HOLDINGS LTD: ZCL.XJSE
# TRANSCEND RES PROP FD LD: TPF.XJSE
# YEBOYETHU (RF) LTD: YYLBEE.XJSE
# CAPITAL APPRECIATION LTD: CTA.XJSE
# TEXTON PROPERTY FUND LTD: TEX.XJSE
# STELLAR CAP PARTNERS LTD: SCP.XJSE
# SASFIN HOLDINGS LTD: SFN.XJSE
# ANCHOR GROUP LIMITED: ACG.XJSE
# BELL EQUIPMENT LTD: BEL.XJSE
# HUGE GROUP LTD: HUG.XJSE
# MARSHALL MONTEAGLE PLC: MMP.XJSE
# WESIZWE PLATINUM LTD: WEZ.XJSE
# VALUE GROUP LTD: VLE.XJSE
# AYO TECH SOLUTIONS LTD: AYO.XJSE
# DENEB INVESTMENTS LTD: DNB.XJSE
# ONELOGIX GROUP LTD: OLG.XJSE
# NOVUS HOLDINGS LIMITED: NVS.XJSE
# QUANTUM FOODS HLDGS LTD: QFH.XJSE
# NU-WORLD HLDGS LTD: NWL.XJSE
# NVEST FINANCIAL HLDGS LTD: NVE.XJSE
# MC MINING LIMITED: MCZ.XJSE
# EOH HOLDINGS LTD: EOH.XJSE
# REBOSIS PROPERTY FUND LTD A: REA.XJSE
# HULAMIN LTD: HLM.XJSE
# NEWPARK REIT LTD: NRL.XJSE
# WESCOAL HOLDINGS LTD: WSL.XJSE
# TREMATON CAPITAL INV LTD: TMT.XJSE
# BOWLER METCALF LTD: BCF.XJSE
# MUSTEK LTD: MST.XJSE
# RH BOPHELO LIMITED: RHB.XJSE
# CROOKES BROTHERS LTD: CKS.XJSE
# ORION MINERALS LIMITED: ORN.XJSE
# AFRICAN PHOENIX INV LTD: AXL.XJSE
# EFFICIENT GROUP LTD: EFG.XJSE
# TRANSPACO LTD: TPC.XJSE
# TONGAAT HULETT LTD: TON.XJSE
# DELTA PROPERTY FUND LTD: DLT.XJSE
# RESOURCE GENERATION LTD: RSG.XJSE
# INSIMBI IND HLDGS LTD: ISB.XJSE
# AFRICAN EQUITY EMP INV LTD: AEE.XJSE
# AVENG GROUP LIMITED: AEG.XJSE
# REX TRUEFORM GROUP LTD: RTO.XJSE
# YORK TIMBER HOLDINGS LTD: YRK.XJSE
# REX TRUEFORM GROUP -N-: RTN.XJSE
# VUNANI LTD: VUN.XJSE
# KORE POTASH PLC: KP2.XJSE
# PURPLE GROUP LTD: PPE.XJSE
# CONDUIT CAPITAL LTD: CND.XJSE
# ARGENT INDUSTRIAL LTD: ART.XJSE
# TRELLIDOR HLDGS LTD: TRL.XJSE
# SANTOVA LOGISTICS LTD: SNV.XJSE
# AFRICAN & OVER ENT LTD -N: AON.XJSE
# CALGRO M3 HLDGS LTD: CGR.XJSE
# BUFFALO COAL CORP: BUC.XJSE
# AFRICAN & OVER ENT LTD: AOO.XJSE
# PREMIER FISHING BRANDS LTD: PFB.XJSE
# ASTORIA INVESTMENTS LTD: ARA.XJSE
# WORKFORCE HOLDINGS LTD: WKF.XJSE
# NIVEUS INVESTMENTS LTD: NIV.XJSE
# HULISANI LIMITED: HUL.XJSE
# PBT GROUP LIMITED: PBG.XJSE
# GAIA INFRASTRUCT CAP LTD: GAI.XJSE
# ADAPT IT HOLDINGS LTD: ADI.XJSE
# EASTERN PLATINUM LTD: EPS.XJSE
# ALARIS HOLDINGS LTD: ALH.XJSE
# CHROMETCO LTD: CMO.XJSE
# CONS INFRASTRUCTURE GRP LTD: CIL.XJSE
# REBOSIS PROPERTY FUND LTD: REB.XJSE
# ANDULELA INV HLDGS LTD: AND.XJSE
# LONDON FIN INV GROUP PLC: LNF.XJSE
# SEBATA HOLDINGS LTD: SEB.XJSE
# ASCENDIS HEALTH LTD: ASC.XJSE
# SEPHAKU HOLDINGS LTD: SEP.XJSE
# LABAT AFRICA LTD: LAB.XJSE
# AFRICAN MEDIA ENT LTD: AME.XJSE
# PHUMELELA GAME LEISURE: PHM.XJSE
# PUTPROP LTD: PPR.XJSE
# UNICORN CAPITAL PNR LTD: UCP.XJSE
# RANDGOLD & EXPL CO LTD: RNG.XJSE
# GO LIFE INTERNATIONAL LD: GLI.XJSE
# NUTRITIONAL HOLDINGS LTD: NUT.XJSE
# KIBO ENERGY PLC: KBO.XJSE
# EFORA ENERGY LIMITED: EEL.XJSE
# KAYDAV GROUP LTD: KDV.XJSE
# BAUBA RESOURCES LIMITED: BAU.XJSE
# COGNITION HOLDINGS LTD: CGN.XJSE
# ELB GROUP LTD: ELR.XJSE
# ISA HOLDINGS LIMITED: ISA.XJSE
# INDEQUITY GROUP LTD: IDQ.XJSE
# PSV HOLDINGS LTD: PSV.XJSE
# ADVANCED HEALTH LTD: AVL.XJSE
# CSG HOLDINGS LTD: CSG.XJSE
# PRIMESERV GROUP LTD: PMV.XJSE
# TASTE HLDGS LTD: TAS.XJSE
# ETION LIMITED: ETO.XJSE
# SOUTH OCEAN HOLDINGS LTD: SOH.XJSE
# ELLIES HOLDINGS LTD: ELI.XJSE
# NICTUS LTD: NCS.XJSE
# JASCO ELECTRON HLDGS LTD: JSC.XJSE
# STEFANUTI STCK HLDGS LTD: SSK.XJSE
# SILVERBRIDGE HOLDINGS: SVB.XJSE
# TELEMASTER HOLDINGS LTD: TLM.XJSE
# ECSPONENT LIMITED: ECS.XJSE
# EUROPA METALS LIMITED: EUZ.XJSE
# PEMBURY LIFESTYLE GRP LT: PEM.XJSE
# VISUAL INTERNATIONAL HLDGS LTD: VIS.XJSE
# SPANJAARD LIMITED: SPA.XJSE
# MAZOR GROUP LTD: MZR.XJSE
# AFRICAN DAWN CAPITAL LTD: ADW.XJSE
# ACCENTUATE LIMITED: ACE.XJSE
# ABSA BANK LTD PREF: ABSP.XJSE
# FIRSTRAND LTD B PREF: FSRP.XJSE
# STD BANK GROUP 6,5%PREF: SBKP.XJSE
# STANDARD BANK GROUP PREF: SBPP.XJSE
# INVESTEC LTD PREF: INPR.XJSE
# INVESTEC PLC PREF (RAND): INPPR.XJSE
# INVESTEC PLC PREF: INPP.XJSE
# DISCOVERY LTD B PREF: DSBP.XJSE
# NETCARE LIMITED PREF: NTCP.XJSE
# LIBERTY HLDGS 11C PREF: LBHP.XJSE
# CAPITEC BANK HLDGS PREF: CPIP.XJSE
# AECI LIMITED 5,5% PREF: AFEP.XJSE
# GRINDROD LTD PREF: GNDP.XJSE
# CAXTON CTP PUBLISH 6%PF: CATP.XJSE
# NAMPAK LTD 6%PREF: NPKP.XJSE
# PSG FINANCIAL SERV PREF: PGFP.XJSE
# INVICTA HLDGS LTD PREF: IVTP.XJSE
# SASFIN HLDGS LTD PREF: SFNP.XJSE
# RECM AND CALIBRE LIMITED: RACP.XJSE
# ECSPONENT PREF SHARE C2: ECSP6.XJSE
# 4Sight Holdings Limited: 4SI.XJSE
# Arden Capital Limited: ACZ.XJSE
# AH-Vest Limited: AHL.XJSE
# Cloud Atlas AMI Big50 ex-SA ETF: AMIB50.XJSE
# Cloud Atlas (RF) Proprietary Limited - AMI Real Es: AMIRE.XJSE
# Converting tickers to list...
# Output dataframe...
# Writing csv file...
# Saving JSE data to disc...
# Saving csv files for each stock to disc...

# %% [markdown]
# ###Indicators

# %%
# %matplotlib inline
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import pandas as pd
from pathlib import Path
import pandas as pd
import stockstats
from stockstats import StockDataFrame as sdf
import glob

plt.rcParams["figure.figsize"] = (12, 9) # (w, h)
plt.ioff()

tickers = pd.read_csv('/content/Stocks_final3/tickers.csv', header=None)[1].tolist()
stocks = (
    (pd.concat(
        [pd.read_csv(f"/content/Stocks_final3/{ticker}.csv",parse_dates=None, index_col=0)[
        'close'].rename(ticker)
        for ticker in tickers],
        axis=1,
        sort=True)
    )
)
stocks = stocks.loc[:,~stocks.columns.duplicated()]

from scipy.stats import linregress
def momentum(closes):
    returns = np.log(closes)
    x = np.arange(len(returns))
    slope, _, rvalue, _, _ = linregress(x, returns)
    return ((1 + slope) ** 252) * (rvalue ** 2)  # annualize slope and multiply by R^2

momentums = stocks.copy(deep=True)
for ticker in tickers:
    momentums[ticker] = stocks[ticker].rolling(90).apply(momentum, raw=False)

result = momentums.sort_values(by =ranking_day, axis = 1, ascending =False)
result.reset_index(inplace=True)
res=result[~(result['date'] < ranking_day)].dropna(axis=1)

mes = res.reindex(columns = res.columns.tolist()
                                  + ['empty'])

df = mes.set_index(['empty']).stack().reset_index(name='index').rename(columns={'level_2':'date'})

df.columns = df.iloc[0]

df.index = list(df.index)

df.columns.values[0] = "empty"
df.columns.values[1] = "symbol"
df.columns.values[2] = "momentum_score"

df=df.drop(['empty'], axis=1)

finalframe=df.drop(index=0)

finalframe['momentum_score'] =finalframe['momentum_score'].astype(float)

finalframe['rank']=finalframe['momentum_score'].rank(ascending=False)

finalframe['momentum_score'] =finalframe['momentum_score'].astype(float)

#finalframe.style.format({'momentum_score':"{:.2f}"})

Mylist = finalframe["symbol"].tolist()

finalframe.set_index('symbol',inplace=True)

final = pd.concat([df1, df2], axis=1, join='inner')
final.columns.values[3] = "tickers"
final.columns = final.columns.astype(str)

final.set_index('tickers', inplace=True)
Yes = final.reindex(Mylist)

rt = pd.concat([finalframe, Yes], axis=1, join='inner')

rt = rt.iloc[:, [2, 3, 4, 0, 1]]

#rt.style.format({'momentum_score':"{:.2f}"})

# get names of indexes for which column "momentum_score" has value > 40%
index_names = rt[(rt['momentum_score'] < 0.001)].index

# drop these given row indexes from dataFrame
rt.drop(index_names, inplace = True)

rt.reset_index(inplace=True)

lowranked = rt [( rt ['rank'] >= 71)].index

# drop these given row indexes from dataFrame
rt.drop( lowranked, inplace = True)

My_final_list = rt["index"].tolist()

rt.set_index('index',inplace=True)

rt.to_csv(ranking_table)
final_table_columns = My_final_list
final_table =stocks.drop(columns=[col for col in stocks if col not in final_table_columns])

for column in final_table.columns:
    final_table[column].to_csv('/content/momentum_tickers/' + column + '.csv')

vola_table = Path('/content/momentum_tickers')

for file in vola_table.glob('*.JO.csv'): #create iteratable & iterate on it.
    vola_df = pd.read_csv(file)
    vola_df.columns.values[1] = "close"
    vola_df["20d_vol"] = vola_df["close"].pct_change().rolling(20).std()
    #vola_df = sdf.retype(vola_df)['close_90_roc']
    #vola_df = pd.DataFrame(vola_df)
    vola_df['date'] =  pd.to_datetime(vola_df['date']).dt.strftime('%Y-%m-%d')
    vola_df.set_index('date', inplace=True)
    stockstats_df = sdf.retype(vola_df)['close_90_roc']
    df = pd.DataFrame(stockstats_df)
    vola_file_name= file.parent.joinpath(f"/content/ranking_table/{file.stem}.csv")
    vola_df.to_csv(vola_file_name) #, index=None, encoding='utf-8-sig', decimal=',')

vola_table1 = Path('/content/ranking_table')

for file in vola_table1.glob('*.JO.csv'): #create iteratable & iterate on it.
    vola_df1 = pd.read_csv(file).tail(1)

    vola_df1['date'] =  pd.to_datetime(vola_df1['date']).dt.strftime('%Y-%m-%d')

    vola_df1.set_index('date', inplace=True)

    vola_file_name1= file.parent.joinpath(f"/content/momentum_stocks/{file.stem}.csv")

    vola_df1.to_csv(vola_file_name1)


# set search path and glob for files
# here we want to look for csv files in the input directory
path = '/content/'
files = glob.glob(path + '/momentum_stocks/*.csv')

# create empty list to store dataframes
li = []

# loop through list of files and read each one into a dataframe and append to list
for f in files:
    # get filename
    stock = os.path.basename(f)
    # read in csv
    temp_df = pd.read_csv(f)
    # create new column with filename
    temp_df['ticker'] = stock
    # data cleaning to remove the .csv
    temp_df['ticker'] = temp_df['ticker'].replace('.csv', '', regex=True)
    # append df to list
    li.append(temp_df)
    #print(f'Successfully created dataframe for {stock} with shape {temp_df.shape}')

# concatenate our list of dataframes into one!
df = pd.concat(li)

ranking_list =df.set_index('ticker').reindex(My_final_list).reset_index()

inv_vol = 1 / ranking_list["20d_vol"]
sum_inv_vol=inv_vol.sum()
vol_targets = inv_vol / sum_inv_vol
ranking_list["weight"] = vol_targets

ranking_list.set_index('ticker', inplace=True)

final_list = pd.concat([rt,ranking_list], axis=1, join='inner')

stockprice = final_list["close"] / 100
pos_weight = portfolio_value * final_list["weight"]
final_list["units"] = pos_weight / stockprice
final_list["ZAR"] = stockprice * final_list["units"]


sma = Path('/content/ranking_table')

for file in sma.glob('*.JO.csv'): #create iteratable & iterate on it.
    sma = pd.read_csv(file)
    sma['date'] =  pd.to_datetime(sma['date']).dt.strftime('%Y-%m-%d')
    sma.set_index('date', inplace=True)

    '''Function'''

    sma['100d_sma'] = sma['close'].rolling(100).mean()

    #sma['index_sma']=index['Close'].rolling(200).mean()

    #sma['trend'] = np.where(sma['close'] > sma['100d_sma'], True, False)

    sma['index'] = index['Close']

    sma['index_sma']=index['Close'].rolling(200).mean()

    sma['trend'] = np.where(sma['close'] > sma['100d_sma'], True, False)

    sma['index_trend']= np.where(sma['index'] > sma['index_sma'], True, False)

    sma_file_name= file.parent.joinpath(f"/content/sma_data/{file.stem}.csv")

    sma.to_csv(sma_file_name)

buy_table = Path('/content/sma_data')

for file in buy_table.glob('*.JO.csv'): #create iteratable & iterate on it.
    buy_list_df = pd.read_csv(file).tail(1)

    buytable = file.parent.joinpath(f"/content/buy_list/{file.stem}.csv")

    buy_list_df.to_csv(buytable)

# %% [markdown]
# ###Initial Portfolio and Ranking Table

# %%
import pandas as pd
import glob

# set search path and glob for files
# here we want to look for csv files in the input directory
path1 = '/content/'
files1 = glob.glob(path1 + '/buy_list/*.csv')

# create empty list to store dataframes
li1 = []

# loop through list of files and read each one into a dataframe and append to list
for f1 in files1:
    # get filename
    stock1 = os.path.basename(f1)
    # read in csv
    temp_df1 = pd.read_csv(f1)
    # create new column with filename
    temp_df1['ticker'] = stock1
    # data cleaning to remove the .csv
    temp_df1['ticker'] = temp_df1['ticker'].replace('.csv', '', regex=True)
    # append df to list
    li1.append(temp_df1)
    #print(f'Successfully created dataframe for {stock1} with shape {temp_df1.shape}')

# concatenate our list of dataframes into one!
Buy = pd.concat(li1)

buying_list = Buy.set_index('ticker').reindex(My_final_list)#.reset_index()

final_buy_list = pd.concat([final_list, buying_list], axis=1, join='inner')

#define list of columns range
cols = [x for x in range(final_buy_list.shape[1])]

#remove second column in DataFrame
cols.remove(12)
cols.remove(13)
cols.remove(14)
cols.remove(15)
cols.remove(16)#view resulting DataFrame
final_buy_list2 =final_buy_list.iloc[:, cols]
final_buy_list2.info()

final_buy_list2 = final_buy_list2.loc[final_buy_list2.trend, :]

index_names1 = final_buy_list2[(final_buy_list2['close_90_roc'] >= 15)].index

# drop these given row indexes from dataFrame
final_buy_list2.drop(index_names1, inplace = True)
final_buy_list2.to_csv(portfolio)
final_buy_list2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70 entries, TLM.JO to CSB.JO
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            70 non-null     object
#  1   symbol          70 non-null     object
#  2   ticker          70 non-null     object
#  3   momentum_score  70 non-null     float64
#  4   rank            70 non-null     float64
#  5   date            70 non-null     object
#  6   close           70 non-null     float64
#  7   20d_vol         70 non-null     float64
#  8   close_90_roc    69 non-null     float64
#  9   weight          70 non-null     float64
#  10  units           70 non-null     float64
#  11  ZAR             70 non-null     float64
#  12  100d_sma        61 non-null     float64
#  13  index           70 non-null     float64
#  14  index_sma       70 non-null     float64
#  15  trend           70 non-null     bool
#  16  index_trend     70 non-null     bool
# dtypes: bool(2), float64(11), object(4)
# memory usage: 10.9+ KB
#                                name      symbol ticker  momentum_score  rank  \
# GLI.JO     GO LIFE INTERNATIONAL LD    GLI.XJSE    GLI        2.349074   3.0
# TXT.JO    TEXTAINER GROUP HLDGS LTD    TXT.XJSE    TXT        1.158701   5.0
# SPG.JO              SUPER GROUP LTD    SPG.XJSE    SPG        1.155566   6.0
# QFH.JO      QUANTUM FOODS HLDGS LTD    QFH.XJSE    QFH        1.080770   7.0
# ART.JO        ARGENT INDUSTRIAL LTD    ART.XJSE    ART        0.833925  11.0
# MTH.JO           MOTUS HOLDINGS LTD    MTH.XJSE    MTH        0.833385  12.0
# CML.JO     CORONATION FUND MNGRS LD    CML.XJSE    CML        0.769543  14.0
# INL.JO                 INVESTEC LTD    INL.XJSE    INL        0.757200  15.0
# CLI.JO                CLIENTELE LTD    CLI.XJSE    CLI        0.754481  16.0
# ABG.JO           ABSA GROUP LIMITED    ABG.XJSE    ABG        0.732318  17.0
# INP.JO                 INVESTEC PLC    INP.XJSE    INP        0.716575  18.0
# MTM.JO       MOMENTUM MET HLDGS LTD    MTM.XJSE    MTM        0.639703  19.0
# VKE.JO     VUKILE PROPERTY FUND LTD    VKE.XJSE    VKE        0.428096  25.0
# MPT.JO                MPACT LIMITED    MPT.XJSE    MPT        0.365670  33.0
# SYG.JO               SYGNIA LIMITED    SYG.XJSE    SYG        0.263364  48.0
# MTNZF.JO          MTN ZAKHELE FUTHI  MTNZF.XJSE  MTNZF        0.251352  49.0
# SEP.JO         SEPHAKU HOLDINGS LTD    SEP.XJSE    SEP        0.231695  51.0
# PPH.JO          PEPKOR HOLDINGS LTD    PPH.XJSE    PPH        0.196093  59.0
# SOL.JO                SASOL LIMITED    SOL.XJSE    SOL        0.174199  63.0
# TRE.JO                  TRENCOR LTD    TRE.XJSE    TRE        0.136595  68.0
# CSB.JO                CASHBUILD LTD    CSB.XJSE    CSB        0.088030  70.0
#
#                 date    close   20d_vol  close_90_roc    weight         units  \
# GLI.JO    2023-08-29      1.0  0.255209      0.000000  0.001186  18599.190436
# TXT.JO    2023-08-29  73177.0  0.021904      9.710645  0.013822      2.961416
# SPG.JO    2023-08-29   3460.0  0.017817      8.226462  0.016992     76.996895
# QFH.JO    2023-08-29    485.0  0.009885      9.977324  0.030627    990.099499
# ART.JO    2023-08-29   1555.0  0.016119      6.799451  0.018782    189.377653
# MTH.JO    2023-08-29  10590.0  0.022378     10.312500  0.013529     20.029368
# CML.JO    2023-08-29   3235.0  0.009263     10.334243  0.032682    158.394828
# INL.JO    2023-08-29  10872.0  0.014619     10.386841  0.020708     29.864087
# CLI.JO    2023-08-29   1116.0  0.029167      6.387035  0.010380    145.825029
# ABG.JO    2023-08-29  18530.0  0.017575      5.218329  0.017226     14.575134
# INP.JO    2023-08-29  11000.0  0.013256     10.597225  0.022839     32.553339
# MTM.JO    2023-08-29   1995.0  0.018677     10.342920  0.016209    127.389205
# VKE.JO    2023-08-29   1335.0  0.012583      3.810264  0.024061    282.578641
# MPT.JO    2023-08-29   3036.0  0.019995      9.208633  0.015141     78.193922
# SYG.JO    2023-08-29   1825.0  0.016832      7.924305  0.017986    154.520604
# MTNZF.JO  2023-08-29   2100.0  0.031057      7.692308  0.009748     72.780404
# SEP.JO    2023-08-29    100.0  0.117622     -6.542056  0.002574    403.553837
# PPH.JO    2023-08-29   1660.0  0.015221     -2.810304  0.019891    187.867104
# SOL.JO    2023-08-29  24431.0  0.026223      2.543547  0.011545      7.409103
# TRE.JO    2023-08-29    661.0  0.032991      4.588608  0.009177    217.669179
# CSB.JO    2023-08-29  18650.0  0.025789     11.603136  0.011739      9.868946
#
#                   ZAR    100d_sma   index   index_sma  trend  index_trend
# GLI.JO     185.991904      0.8231  3759.0  3808.92188   True        False
# TXT.JO    2167.075728  71317.1000  3759.0  3808.92188   True        False
# SPG.JO    2664.092574   3241.2500  3759.0  3808.92188   True        False
# QFH.JO    4801.982568    461.6500  3759.0  3808.92188   True        False
# ART.JO    2944.822512   1533.2500  3759.0  3808.92188   True        False
# MTH.JO    2121.110089   9757.3800  3759.0  3808.92188   True        False
# CML.JO    5124.072676   3167.0500  3759.0  3808.92188   True        False
# INL.JO    3246.823494  10574.2200  3759.0  3808.92188   True        False
# CLI.JO    1627.407326   1083.4600  3759.0  3808.92188   True        False
# ABG.JO    2700.772379  17217.7600  3759.0  3808.92188   True        False
# INP.JO    3580.867267  10663.9300  3759.0  3808.92188   True        False
# MTM.JO    2541.414638   1827.9100  3759.0  3808.92188   True        False
# VKE.JO    3772.424862   1274.5000  3759.0  3808.92188   True        False
# MPT.JO    2373.967463   2704.5300  3759.0  3808.92188   True        False
# SYG.JO    2820.001030   1729.6200  3759.0  3808.92188   True        False
# MTNZF.JO  1528.388474   1919.8500  3759.0  3808.92188   True        False
# SEP.JO     403.553837     96.3700  3759.0  3808.92188   True        False
# PPH.JO    3118.593924   1639.7900  3759.0  3808.92188   True        False
# SOL.JO    1810.117971  24066.8000  3759.0  3808.92188   True        False
# TRE.JO    1438.793275    659.4900  3759.0  3808.92188   True        False
# CSB.JO    1840.558358  16935.7600  3759.0  3808.92188   True        False

# %% [markdown]
# ###List to Liquidate current positions

# %%
sell_list = final_buy_list [~final_buy_list
 ["trend"]]
#sell_list.info()
dqs = sell_list ["ticker"].tolist()
cpf=pd.read_csv(current_portfolio)
#sell_list
liquidate = cpf.loc[cpf['ticker'].isin (dqs)].reset_index (drop=True)

newpf = cpf[~cpf['ticker'].isin(liquidate['ticker'])]
dfnew = newpf[~newpf['ticker'].isin(final_buy_list2['ticker'])]

remove = dfnew ["ticker"].tolist()
now = newpf[~newpf['ticker'].isin(dfnew['ticker'])]
now.set_index("ticker", inplace=True)
rebalance = now ["symbol"].tolist()

print(f"Liquidate disqualified stocks = {liquidate['name']}")
print(f"Liquidate stocks not in ranking table= {dfnew['name']}")
print(f"Portfolio after liquidation= {now['name']}")
# Out:
# Liquidate disqualified stocks = 0                 TRENCOR LTD
# 1         PEPKOR HOLDINGS LTD
# 2       HUDACO INDUSTRIES LTD
# 3    JUBILEE METALS GROUP PLC
# 4                 PROSUS N.V.
# Name: name, dtype: object
# Liquidate stocks not in ranking table= 0                  VUNANI LTD
# 1         SEBATA HOLDINGS LTD
# 5                  REMGRO LTD
# 7                 REUNERT LTD
# 13       SPUR CORPORATION LTD
# 15    4Sight Holdings Limited
# 17         NU-WORLD HLDGS LTD
# 18           RAUBEX GROUP LTD
# 19       DISCOVERY LTD B PREF
# 20     METROFILE HOLDINGS LTD
# 22                BIDVEST LTD
# 25          ENX GROUP LIMITED
# 26             SANTAM LIMITED
# Name: name, dtype: object
# Portfolio after liquidation= ticker
# SRE        SIRIUS REAL ESTATE LTD
# ART         ARGENT INDUSTRIAL LTD
# LHC    LIFE HEALTHC GRP HLDGS LTD
# ABG            ABSA GROUP LIMITED
# ASC           ASCENDIS HEALTH LTD
# CLI                 CLIENTELE LTD
# QFH       QUANTUM FOODS HLDGS LTD
# SPG               SUPER GROUP LTD
# MTM        MOMENTUM MET HLDGS LTD
# Name: name, dtype: object

# %% [markdown]
# ###Update Ranking Table

# %%
portfolio_value2=129286.63

final_weights = final_buy_list
final_weights.set_index('rank').reset_index()
final_w = [x for x in range(final_weights.shape[1])]

final_w.remove(12)
final_w.remove(13)
final_w.remove(14)
final_w.remove(15)
final_w.remove(16)
final_weights2=final_weights.iloc[:, cols]
inv_vol2 = 1 / final_weights2["20d_vol"]
sum_inv_vol2 =inv_vol2.sum()
vol_targets2 = inv_vol2 / sum_inv_vol2
final_weights2["weight"] = vol_targets2

final_weights2.set_index('symbol', inplace=True)

stockprice2 = final_weights2["close"] / 100
pos_weight2 = portfolio_value2 * final_weights2["weight"]
final_weights2["units"] = pos_weight2 / stockprice2
final_weights2["ZAR"] = stockprice2 * final_weights2["units"]
final_weights2.to_csv(ranking_table)

final_weights2
# Out:
# <ipython-input-39-a784903a1911>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_weights2["weight"] = vol_targets2
# <ipython-input-39-a784903a1911>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_weights2["units"] = pos_weight2 / stockprice2
# <ipython-input-39-a784903a1911>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_weights2["ZAR"] = stockprice2 * final_weights2["units"]
#                                name ticker  momentum_score  rank        date  \
# symbol
# TLM.XJSE    TELEMASTER HOLDINGS LTD    TLM      119.321575   1.0  2023-08-29
# OAO.XJSE                  OANDO PLC    OAO        3.334711   2.0  2023-08-29
# GLI.XJSE   GO LIFE INTERNATIONAL LD    GLI        2.349074   3.0  2023-08-29
# TRU.XJSE          TRUWORTHS INT LTD    TRU        2.301490   4.0  2023-08-29
# TXT.XJSE  TEXTAINER GROUP HLDGS LTD    TXT        1.158701   5.0  2023-08-29
# ...                             ...    ...             ...   ...         ...
# HDC.XJSE      HUDACO INDUSTRIES LTD    HDC        0.161971  66.0  2023-08-29
# RCL.XJSE          RCL FOODS LIMITED    RCL        0.147784  67.0  2023-08-29
# TRE.XJSE                TRENCOR LTD    TRE        0.136595  68.0  2023-08-29
# DLT.XJSE    DELTA PROPERTY FUND LTD    DLT        0.102205  69.0  2023-08-29
# CSB.XJSE              CASHBUILD LTD    CSB        0.088030  70.0  2023-08-29
#
#             close    20d_vol  close_90_roc    weight         units  \
# symbol
# TLM.XJSE    110.0  22.149720     29.411765  0.000014      1.606461
# OAO.XJSE     25.0   0.294769     19.047619  0.001027    531.140741
# GLI.XJSE      1.0   0.255209      0.000000  0.001186  15336.818546
# TRU.XJSE   7134.0   0.013953     32.380776  0.021697     39.321444
# TXT.XJSE  73177.0   0.021904      9.710645  0.013822      2.441972
# ...           ...        ...           ...       ...           ...
# HDC.XJSE  15400.0   0.019088      0.000000  0.015861     13.315408
# RCL.XJSE   1100.0   0.029415     -5.008636  0.010292    120.967319
# TRE.XJSE    661.0   0.032991      4.588608  0.009177    179.489141
# DLT.XJSE     13.0   0.113117    -45.833333  0.002676   2661.696929
# CSB.XJSE  18650.0   0.025789     11.603136  0.011739      8.137893
#
#                   ZAR    100d_sma   index   index_sma  trend  index_trend
# symbol
# TLM.XJSE     1.767107     79.8695  3759.0  3808.92188   True        False
# OAO.XJSE   132.785185     14.7924  3759.0  3808.92188   True        False
# GLI.XJSE   153.368185      0.8231  3759.0  3808.92188   True        False
# TRU.XJSE  2805.191806   5762.1600  3759.0  3808.92188   True        False
# TXT.XJSE  1786.962036  71317.1000  3759.0  3808.92188   True        False
# ...               ...         ...     ...         ...    ...          ...
# HDC.XJSE  2050.572755  15477.7500  3759.0  3808.92188  False        False
# RCL.XJSE  1330.640514         NaN  3759.0  3808.92188  False        False
# TRE.XJSE  1186.423219    659.4900  3759.0  3808.92188   True        False
# DLT.XJSE   346.020601     18.7900  3759.0  3808.92188  False        False
# CSB.XJSE  1517.717110  16935.7600  3759.0  3808.92188   True        False
#
# [70 rows x 16 columns]

# %%
ticker
# Out:
# yfinance.Ticker object <INPR.JO>

# %%
todays_ranking_table = pd.read_csv("/content/ranking_table290823.csv")
todays_ranking_table

# %% [markdown]
# ###Rebalance Positions

# %%
rebalance1 =final_weights2[final_weights2['name'].isin(now['name'])]

index_names4 = rebalance1 [( rebalance1 ['rank'] >= 71)].index

# drop these given row indexes from dataFrame
Allsale =rebalance1.drop(index_names4)

rebalance3 = rebalance1.reindex(rebalance).set_index('ticker')


now.reset_index(inplace=True)
rebalance3.reset_index(inplace=True)

rebalance3 ["bs"] = rebalance3["units"]-now["units"]
index_names5 = rebalance3 [( rebalance3 ['rank'] >= 71)].index

# drop these given row indexes from dataFrame
rebalance3.drop(index_names5, inplace = True)
rebalance3
# Out:
#   ticker                        name  momentum_score  rank        date  \
# 0    SRE      SIRIUS REAL ESTATE LTD        0.314125  30.0  2023-08-23
# 1    ART       ARGENT INDUSTRIAL LTD        0.922613   6.0  2023-08-23
# 2    LHC  LIFE HEALTHC GRP HLDGS LTD        0.068753  61.0  2023-08-23
# 3    ABG          ABSA GROUP LIMITED        0.349355  24.0  2023-08-23
# 4    ASC         ASCENDIS HEALTH LTD        0.022665  67.0  2023-08-23
# 5    CLI               CLIENTELE LTD        0.772767  10.0  2023-08-23
# 6    QFH     QUANTUM FOODS HLDGS LTD        1.081738   3.0  2023-08-23
# 7    SPG             SUPER GROUP LTD        0.954451   5.0  2023-08-23
# 8    MTM      MOMENTUM MET HLDGS LTD        0.475684  16.0  2023-08-23
#
#      close   20d_vol  close_90_roc    weight        units          ZAR  \
# 0   1935.0  0.013488     10.068259  0.021140   175.350446  3393.031124
# 1   1570.0  0.016539      6.802721  0.017240   176.248020  2767.093906
# 2   2048.0  0.012266      5.458290  0.023246   182.176380  3730.972266
# 3  18273.0  0.017633     -1.243042  0.016171    14.203978  2595.492849
# 4     63.0  0.032527      1.612903  0.008766  2233.349443  1407.010149
# 5   1140.0  0.029189      8.571429  0.009769   137.535161  1567.900839
# 6    485.0  0.010153     12.529002  0.028085   929.402968  4507.604395
# 7   3505.0  0.019514      8.986318  0.014612    66.912906  2345.297340
# 8   1928.0  0.013641      5.643836  0.020904   174.019233  3355.090815
#
#    100d_sma         index     index_sma  trend  index_trend           bs
# 0   1925.14  74022.578125  76368.594883   True        False   174.062970
# 1   1529.39  74022.578125  76368.594883   True        False   173.870375
# 2   2025.28  74022.578125  76368.594883   True        False   179.833134
# 3  17207.34  74022.578125  76368.594883   True        False    13.985873
# 4     62.87  74022.578125  76368.594883   True        False  2208.270741
# 5   1079.18  74022.578125  76368.594883   True        False   136.780709
# 6    460.27  74022.578125  76368.594883   True        False   925.803941
# 7   3234.17  74022.578125  76368.594883   True        False    65.383869
# 8   1818.96  74022.578125  76368.594883   True        False   171.917563

# %% [markdown]
# ###Enter New Positions

# %%
ranking_table1 = final_weights2.reindex().set_index('ticker')
#ranking_table1["bs"] = ranking_table1["units"] * 1
ranking_table1.reset_index(inplace=True)

ranking_table1 = ranking_table1.loc[ranking_table1.trend, :]
index_names2 = ranking_table1 [( ranking_table1 ['close_90_roc'] >= 15)].index

# drop these given row indexes from dataFrame
ranking_table1.drop(index_names2, inplace = True)

buynew = ranking_table1 [~ ranking_table1 ['ticker'].isin( rebalance3 ['ticker'])]
index_names2 = ranking_table1 [( ranking_table1 ['close_90_roc'] >= 15)].index

# drop these given row indexes from dataFrame
ranking_table1.drop(index_names2, inplace = True)

buynamesnew2 = buynew [( buynew ['rank'] >= 71)].index

# drop these given row indexes from dataFrame
buynew.drop( buynamesnew2, inplace = True)

buynew
# Out:
# <ipython-input-61-02273f304f57>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   buynew.drop( buynamesnew2, inplace = True)
#    ticker                      name  momentum_score  rank        date  \
# 6     CML  CORONATION FUND MNGRS LD        0.902613   7.0  2023-08-23
# 7     INL              INVESTEC LTD        0.870785   8.0  2023-08-23
# 8     INP              INVESTEC PLC        0.812591   9.0  2023-08-23
# 11    MTH        MOTUS HOLDINGS LTD        0.696434  12.0  2023-08-23
# 33    VKE  VUKILE PROPERTY FUND LTD        0.278954  34.0  2023-08-23
# 44    JSE                   JSE LTD        0.204050  45.0  2023-08-23
# 48    SYG            SYGNIA LIMITED        0.179290  49.0  2023-08-23
# 51    MPT             MPACT LIMITED        0.155712  52.0  2023-08-23
# 54  MTNZF         MTN ZAKHELE FUTHI        0.143076  55.0  2023-08-23
# 57    LAB          LABAT AFRICA LTD        0.096234  58.0  2023-08-23
# 61    DCP   DIS-CHEM PHARMACIES LTD        0.056290  62.0  2023-08-23
# 63    MSP      MAS REAL ESTATE INC.        0.054277  64.0  2023-08-23
# 64    SSK  STEFANUTI STCK HLDGS LTD        0.050256  65.0  2023-08-23
# 65    GLI  GO LIFE INTERNATIONAL LD        0.045265  66.0  2023-08-23
# 68    RDF   REDEFINE PROPERTIES LTD        0.011304  69.0  2023-08-23
# 69    CSB             CASHBUILD LTD        0.011134  70.0  2023-08-23
#
#       close   20d_vol  close_90_roc    weight         units          ZAR  \
# 6    3204.0  0.013260      5.187131  0.021504    107.720103  3451.352094
# 7   10817.0  0.014326      9.717010  0.019904     29.533139  3194.599637
# 8   10900.0  0.013219      9.218437  0.021570     31.761524  3462.006135
# 11  10112.0  0.024584      5.829409  0.011599     18.409873  1861.606396
# 33   1305.0  0.012725      0.772201  0.022408    275.590579  3596.457054
# 44   9727.0  0.017116     -1.925791  0.016660     27.489008  2673.855810
# 48   1770.0  0.030316      2.017291  0.009406     85.289132  1509.617634
# 51   3050.0  0.018752      8.540925  0.015206     80.020468  2440.624282
# 54   2100.0  0.032420     10.410095  0.008795     67.222621  1411.675046
# 57      8.0  0.114660      0.000000  0.002487   4989.325750   399.146060
# 61   2520.0  0.023791     -5.120482  0.011985     76.335853  1923.663494
# 63   2163.0  0.013159      1.216659  0.021669    160.787546  3477.834610
# 64    134.0  0.042379      3.076923  0.006728    805.904851  1079.912500
# 65      1.0  0.255209      0.000000  0.001117  17932.729679   179.327297
# 68    359.0  0.017847     -9.798995  0.015978    714.321843  2564.415418
# 69  18495.0  0.025747      6.901335  0.011075      9.611022  1777.558573
#
#       100d_sma         index     index_sma  trend  index_trend
# 6    3159.7900  74022.578125  76368.594883   True        False
# 7   10533.2000  74022.578125  76368.594883   True        False
# 8   10621.2600  74022.578125  76368.594883   True        False
# 11   9732.6200  74022.578125  76368.594883   True        False
# 33   1271.4800  74022.578125  76368.594883   True        False
# 44   9367.9000  74022.578125  76368.594883   True        False
# 48   1727.6500  74022.578125  76368.594883   True        False
# 51   2700.9900  74022.578125  76368.594883   True        False
# 54   1914.6600  74022.578125  76368.594883   True        False
# 57      7.7300  74022.578125  76368.594883   True        False
# 61   2456.0700  74022.578125  76368.594883   True        False
# 63   2107.0600  74022.578125  76368.594883   True        False
# 64    132.1700  74022.578125  76368.594883   True        False
# 65      0.8131  74022.578125  76368.594883   True        False
# 68    348.5200  74022.578125  76368.594883   True        False
# 69  16933.0900  74022.578125  76368.594883   True        False

# %% [markdown]
# ###Portfolio after position rebalance

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
rebalancex = rebalance3.reset_index().set_index("level_0")
buynewx = buynew.reset_index().set_index("level_0")
new_portfolio2 = rebalancex.append(buynewx, ignore_index=True)
new_portfolio2.drop(columns =["bs"], inplace = True)
rslt_df = new_portfolio2.sort_values(by = 'rank', ascending = True)
rslt_df .ticker = rslt_df.ticker+ '.JO'
Tickers = rslt_df["ticker"].tolist()
sector_list=[]

for tik in Tickers:
    ticker=yf.Ticker(tik)
    sector=ticker.info['sector']
    sector_list.append(sector)

rslt_df ['sector'] = sector_list
rslt_df
# Out:
# <ipython-input-71-5be5fbafb8f0>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_portfolio2 = rebalancex.append(buynewx, ignore_index=True)
#       ticker                        name  momentum_score  rank        date  \
# 6     QFH.JO     QUANTUM FOODS HLDGS LTD        1.081738   3.0  2023-08-23
# 7     SPG.JO             SUPER GROUP LTD        0.954451   5.0  2023-08-23
# 1     ART.JO       ARGENT INDUSTRIAL LTD        0.922613   6.0  2023-08-23
# 9     CML.JO    CORONATION FUND MNGRS LD        0.902613   7.0  2023-08-23
# 10    INL.JO                INVESTEC LTD        0.870785   8.0  2023-08-23
# 11    INP.JO                INVESTEC PLC        0.812591   9.0  2023-08-23
# 5     CLI.JO               CLIENTELE LTD        0.772767  10.0  2023-08-23
# 12    MTH.JO          MOTUS HOLDINGS LTD        0.696434  12.0  2023-08-23
# 8     MTM.JO      MOMENTUM MET HLDGS LTD        0.475684  16.0  2023-08-23
# 3     ABG.JO          ABSA GROUP LIMITED        0.349355  24.0  2023-08-23
# 0     SRE.JO      SIRIUS REAL ESTATE LTD        0.314125  30.0  2023-08-23
# 13    VKE.JO    VUKILE PROPERTY FUND LTD        0.278954  34.0  2023-08-23
# 14    JSE.JO                     JSE LTD        0.204050  45.0  2023-08-23
# 15    SYG.JO              SYGNIA LIMITED        0.179290  49.0  2023-08-23
# 16    MPT.JO               MPACT LIMITED        0.155712  52.0  2023-08-23
# 17  MTNZF.JO           MTN ZAKHELE FUTHI        0.143076  55.0  2023-08-23
# 18    LAB.JO            LABAT AFRICA LTD        0.096234  58.0  2023-08-23
# 2     LHC.JO  LIFE HEALTHC GRP HLDGS LTD        0.068753  61.0  2023-08-23
# 19    DCP.JO     DIS-CHEM PHARMACIES LTD        0.056290  62.0  2023-08-23
# 20    MSP.JO        MAS REAL ESTATE INC.        0.054277  64.0  2023-08-23
# 21    SSK.JO    STEFANUTI STCK HLDGS LTD        0.050256  65.0  2023-08-23
# 22    GLI.JO    GO LIFE INTERNATIONAL LD        0.045265  66.0  2023-08-23
# 4     ASC.JO         ASCENDIS HEALTH LTD        0.022665  67.0  2023-08-23
# 23    RDF.JO     REDEFINE PROPERTIES LTD        0.011304  69.0  2023-08-23
# 24    CSB.JO               CASHBUILD LTD        0.011134  70.0  2023-08-23
#
#       close   20d_vol  close_90_roc    weight         units          ZAR  \
# 6     485.0  0.010153     12.529002  0.028085    929.402968  4507.604395
# 7    3505.0  0.019514      8.986318  0.014612     66.912906  2345.297340
# 1    1570.0  0.016539      6.802721  0.017240    176.248020  2767.093906
# 9    3204.0  0.013260      5.187131  0.021504    107.720103  3451.352094
# 10  10817.0  0.014326      9.717010  0.019904     29.533139  3194.599637
# 11  10900.0  0.013219      9.218437  0.021570     31.761524  3462.006135
# 5    1140.0  0.029189      8.571429  0.009769    137.535161  1567.900839
# 12  10112.0  0.024584      5.829409  0.011599     18.409873  1861.606396
# 8    1928.0  0.013641      5.643836  0.020904    174.019233  3355.090815
# 3   18273.0  0.017633     -1.243042  0.016171     14.203978  2595.492849
# 0    1935.0  0.013488     10.068259  0.021140    175.350446  3393.031124
# 13   1305.0  0.012725      0.772201  0.022408    275.590579  3596.457054
# 14   9727.0  0.017116     -1.925791  0.016660     27.489008  2673.855810
# 15   1770.0  0.030316      2.017291  0.009406     85.289132  1509.617634
# 16   3050.0  0.018752      8.540925  0.015206     80.020468  2440.624282
# 17   2100.0  0.032420     10.410095  0.008795     67.222621  1411.675046
# 18      8.0  0.114660      0.000000  0.002487   4989.325750   399.146060
# 2    2048.0  0.012266      5.458290  0.023246    182.176380  3730.972266
# 19   2520.0  0.023791     -5.120482  0.011985     76.335853  1923.663494
# 20   2163.0  0.013159      1.216659  0.021669    160.787546  3477.834610
# 21    134.0  0.042379      3.076923  0.006728    805.904851  1079.912500
# 22      1.0  0.255209      0.000000  0.001117  17932.729679   179.327297
# 4      63.0  0.032527      1.612903  0.008766   2233.349443  1407.010149
# 23    359.0  0.017847     -9.798995  0.015978    714.321843  2564.415418
# 24  18495.0  0.025747      6.901335  0.011075      9.611022  1777.558573
#
#       100d_sma         index     index_sma  trend  index_trend  \
# 6     460.2700  74022.578125  76368.594883   True        False
# 7    3234.1700  74022.578125  76368.594883   True        False
# 1    1529.3900  74022.578125  76368.594883   True        False
# 9    3159.7900  74022.578125  76368.594883   True        False
# 10  10533.2000  74022.578125  76368.594883   True        False
# 11  10621.2600  74022.578125  76368.594883   True        False
# 5    1079.1800  74022.578125  76368.594883   True        False
# 12   9732.6200  74022.578125  76368.594883   True        False
# 8    1818.9600  74022.578125  76368.594883   True        False
# 3   17207.3400  74022.578125  76368.594883   True        False
# 0    1925.1400  74022.578125  76368.594883   True        False
# 13   1271.4800  74022.578125  76368.594883   True        False
# 14   9367.9000  74022.578125  76368.594883   True        False
# 15   1727.6500  74022.578125  76368.594883   True        False
# 16   2700.9900  74022.578125  76368.594883   True        False
# 17   1914.6600  74022.578125  76368.594883   True        False
# 18      7.7300  74022.578125  76368.594883   True        False
# 2    2025.2800  74022.578125  76368.594883   True        False
# 19   2456.0700  74022.578125  76368.594883   True        False
# 20   2107.0600  74022.578125  76368.594883   True        False
# 21    132.1700  74022.578125  76368.594883   True        False
# 22      0.8131  74022.578125  76368.594883   True        False
# 4      62.8700  74022.578125  76368.594883   True        False
# 23    348.5200  74022.578125  76368.594883   True        False
# 24  16933.0900  74022.578125  76368.594883   True        False
#
#                 sector
# 6   Consumer Defensive
# 7          Industrials
# 1      Basic Materials
# 9   Financial Services
# 10  Financial Services
# 11  Financial Services
# 5   Financial Services
# 12   Consumer Cyclical
# 8   Financial Services
# 3   Financial Services
# 0          Real Estate
# 13         Real Estate
# 14  Financial Services
# 15  Financial Services
# 16   Consumer Cyclical
# 17  Financial Services
# 18          Technology
# 2           Healthcare
# 19          Healthcare
# 20         Real Estate
# 21         Industrials
# 22          Healthcare
# 4           Healthcare
# 23         Real Estate
# 24   Consumer Cyclical

# %% [markdown]
# ###Portfolio after rebalance

# %%
Xxx = final_buy_list2[final_buy_list2['name'].isin(now['name'])]
Xxx2 = Xxx.reset_index().set_index("level_0")
buynewx = buynew.reset_index().set_index("level_0")
new_portfolio3 = Xxx2.append(buynewx, ignore_index=True)
rslt_df2 = new_portfolio3.sort_values(by = 'rank', ascending = True)
inv_vol = 1 / rslt_df2["20d_vol"]
rslt_df2["weight"] = rslt_df2 ["ZAR"] / portfolio_value2
rslt_df2.set_index('rank', inplace=True)
rslt_df2.drop(columns =["symbol"], inplace = True)
rslt_df2 .ticker = rslt_df2.ticker+ '.JO'
Tickers = rslt_df2["ticker"].tolist()
sector_list=[]

for tik in Tickers:
    ticker=yf.Ticker(tik)
    sector=ticker.info['sector']
    sector_list.append(sector)

rslt_df2 ['sector'] = sector_list
rslt_df2
# Out:
# <ipython-input-64-1f4ed2583bbd>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_portfolio3 = Xxx2.append(buynewx, ignore_index=True)
#                             name    ticker  momentum_score        date  \
# rank
# 3.0      QUANTUM FOODS HLDGS LTD    QFH.JO        1.081738  2023-08-23
# 5.0              SUPER GROUP LTD    SPG.JO        0.954451  2023-08-23
# 6.0        ARGENT INDUSTRIAL LTD    ART.JO        0.922613  2023-08-23
# 7.0     CORONATION FUND MNGRS LD    CML.JO        0.902613  2023-08-23
# 8.0                 INVESTEC LTD    INL.JO        0.870785  2023-08-23
# 9.0                 INVESTEC PLC    INP.JO        0.812591  2023-08-23
# 10.0               CLIENTELE LTD    CLI.JO        0.772767  2023-08-23
# 12.0          MOTUS HOLDINGS LTD    MTH.JO        0.696434  2023-08-23
# 16.0      MOMENTUM MET HLDGS LTD    MTM.JO        0.475684  2023-08-23
# 24.0          ABSA GROUP LIMITED    ABG.JO        0.349355  2023-08-23
# 30.0      SIRIUS REAL ESTATE LTD    SRE.JO        0.314125  2023-08-23
# 34.0    VUKILE PROPERTY FUND LTD    VKE.JO        0.278954  2023-08-23
# 45.0                     JSE LTD    JSE.JO        0.204050  2023-08-23
# 49.0              SYGNIA LIMITED    SYG.JO        0.179290  2023-08-23
# 52.0               MPACT LIMITED    MPT.JO        0.155712  2023-08-23
# 55.0           MTN ZAKHELE FUTHI  MTNZF.JO        0.143076  2023-08-23
# 58.0            LABAT AFRICA LTD    LAB.JO        0.096234  2023-08-23
# 61.0  LIFE HEALTHC GRP HLDGS LTD    LHC.JO        0.068753  2023-08-23
# 62.0     DIS-CHEM PHARMACIES LTD    DCP.JO        0.056290  2023-08-23
# 64.0        MAS REAL ESTATE INC.    MSP.JO        0.054277  2023-08-23
# 65.0    STEFANUTI STCK HLDGS LTD    SSK.JO        0.050256  2023-08-23
# 66.0    GO LIFE INTERNATIONAL LD    GLI.JO        0.045265  2023-08-23
# 67.0         ASCENDIS HEALTH LTD    ASC.JO        0.022665  2023-08-23
# 69.0     REDEFINE PROPERTIES LTD    RDF.JO        0.011304  2023-08-23
# 70.0               CASHBUILD LTD    CSB.JO        0.011134  2023-08-23
#
#         close   20d_vol  close_90_roc    weight         units          ZAR  \
# rank
# 3.0     485.0  0.010153     12.529002  0.027435    907.907064  4403.349263
# 5.0    3505.0  0.019514      8.986318  0.014274     65.365296  2291.053608
# 6.0    1570.0  0.016539      6.802721  0.016842    172.171628  2703.094558
# 7.0    3204.0  0.013260      5.187131  0.021504    107.720103  3451.352094
# 8.0   10817.0  0.014326      9.717010  0.019904     29.533139  3194.599637
# 9.0   10900.0  0.013219      9.218437  0.021570     31.761524  3462.006135
# 10.0   1140.0  0.029189      8.571429  0.009543    134.354149  1531.637295
# 12.0  10112.0  0.024584      5.829409  0.011599     18.409873  1861.606396
# 16.0   1928.0  0.013641      5.643836  0.020421    169.994391  3277.491849
# 24.0  18273.0  0.017633     -1.243042  0.015797     13.875458  2535.462414
# 30.0   1935.0  0.013488     10.068259  0.020651    171.294814  3314.554648
# 34.0   1305.0  0.012725      0.772201  0.022408    275.590579  3596.457054
# 45.0   9727.0  0.017116     -1.925791  0.016660     27.489008  2673.855810
# 49.0   1770.0  0.030316      2.017291  0.009406     85.289132  1509.617634
# 52.0   3050.0  0.018752      8.540925  0.015206     80.020468  2440.624282
# 55.0   2100.0  0.032420     10.410095  0.008795     67.222621  1411.675046
# 58.0      8.0  0.114660      0.000000  0.002487   4989.325750   399.146060
# 61.0   2048.0  0.012266      5.458290  0.022708    177.962873  3644.679643
# 62.0   2520.0  0.023791     -5.120482  0.011985     76.335853  1923.663494
# 64.0   2163.0  0.013159      1.216659  0.021669    160.787546  3477.834610
# 65.0    134.0  0.042379      3.076923  0.006728    805.904851  1079.912500
# 66.0      1.0  0.255209      0.000000  0.001117  17932.729679   179.327297
# 67.0     63.0  0.032527      1.612903  0.008564   2181.694923  1374.467801
# 69.0    359.0  0.017847     -9.798995  0.015978    714.321843  2564.415418
# 70.0  18495.0  0.025747      6.901335  0.011075      9.611022  1777.558573
#
#         100d_sma         index     index_sma  trend  index_trend  \
# rank
# 3.0     460.2700  74022.578125  76368.594883   True        False
# 5.0    3234.1700  74022.578125  76368.594883   True        False
# 6.0    1529.3900  74022.578125  76368.594883   True        False
# 7.0    3159.7900  74022.578125  76368.594883   True        False
# 8.0   10533.2000  74022.578125  76368.594883   True        False
# 9.0   10621.2600  74022.578125  76368.594883   True        False
# 10.0   1079.1800  74022.578125  76368.594883   True        False
# 12.0   9732.6200  74022.578125  76368.594883   True        False
# 16.0   1818.9600  74022.578125  76368.594883   True        False
# 24.0  17207.3400  74022.578125  76368.594883   True        False
# 30.0   1925.1400  74022.578125  76368.594883   True        False
# 34.0   1271.4800  74022.578125  76368.594883   True        False
# 45.0   9367.9000  74022.578125  76368.594883   True        False
# 49.0   1727.6500  74022.578125  76368.594883   True        False
# 52.0   2700.9900  74022.578125  76368.594883   True        False
# 55.0   1914.6600  74022.578125  76368.594883   True        False
# 58.0      7.7300  74022.578125  76368.594883   True        False
# 61.0   2025.2800  74022.578125  76368.594883   True        False
# 62.0   2456.0700  74022.578125  76368.594883   True        False
# 64.0   2107.0600  74022.578125  76368.594883   True        False
# 65.0    132.1700  74022.578125  76368.594883   True        False
# 66.0      0.8131  74022.578125  76368.594883   True        False
# 67.0     62.8700  74022.578125  76368.594883   True        False
# 69.0    348.5200  74022.578125  76368.594883   True        False
# 70.0  16933.0900  74022.578125  76368.594883   True        False
#
#                   sector
# rank
# 3.0   Consumer Defensive
# 5.0          Industrials
# 6.0      Basic Materials
# 7.0   Financial Services
# 8.0   Financial Services
# 9.0   Financial Services
# 10.0  Financial Services
# 12.0   Consumer Cyclical
# 16.0  Financial Services
# 24.0  Financial Services
# 30.0         Real Estate
# 34.0         Real Estate
# 45.0  Financial Services
# 49.0  Financial Services
# 52.0   Consumer Cyclical
# 55.0  Financial Services
# 58.0          Technology
# 61.0          Healthcare
# 62.0          Healthcare
# 64.0         Real Estate
# 65.0         Industrials
# 66.0          Healthcare
# 67.0          Healthcare
# 69.0         Real Estate
# 70.0   Consumer Cyclical

# %% [markdown]
# ###Test

# %%
from matplotlib.pyplot import pie, axis, show

rslt_df.groupby('sector').size().plot(kind='pie', autopct='%.2f', textprops={'fontsize': 20})
# Out:
# <Axes: >
